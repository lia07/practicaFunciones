# %% [markdown]
# <a href="https://colab.research.google.com/github/lia07/practicaFunciones/blob/master/DS_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1 Creando un dataFrame usando arrays**

# %% [markdown]
# # **1.1 Opcion 1**

# %% [markdown]
# # **COMO CREAR UN DATAFRAME**
#
# * Arrays
# * Dictionary
# * Archivo CSV

# %%
import pandas as pd
import numpy as np

# %%
#creando un array
data = np.array([[1,4], [2,5], [3,4]])

# %%
#creando un dataframe 
pd.DataFrame(data)
# Out:
#    0  1
# 0  1  4
# 1  2  5
# 2  3  4

# %%
#creando un dataframe 
df = pd.DataFrame(data, index=['row1', 'row2', 'row3'], columns = ['col1', 'col2'])

# %%
#mostrando el dataframe
df
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     4

# %% [markdown]
# # **1.2 Opcion 2**

# %%
#dataframe usando listas
data = [[1,4], [2,5], [3,4]]

# %%
#creando un dataframe 
df = pd.DataFrame(data, index=['row1', 'row2', 'row3'], columns = ['col1', 'col2'])

# %%
#mostrar el dataFrame
df
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     4

# %% [markdown]
# # **2 Creando un dataframe usando diccionarios**

# %%
# listas usadas para el ejemplo
states = ['California', 'Texas', 'Florida', 'New York']
population = [39613493, 29730311, 21944577, 19299981]

# %%
# Almacenando listas en un diccionario
dict_states = {'States':states, 'Population':population}

# %%
# creando el dataframe
df_population = pd.DataFrame(dict_states)

# %%
#mostrando el dataframe
df_population
# Out:
#        States  Population
# 0  California    39613493
# 1       Texas    29730311
# 2     Florida    21944577
# 3    New York    19299981

# %% [markdown]
# # **3 Creando un dataframe con archivos csv**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# leyendo el archivo csv
df_exams = pd.read_csv('/StudentsPerformance.csv')

# %%
#mostrando el dataframe
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %% [markdown]
# # **Como mostrar un dataframe**

# %%
#
import pandas  as pd

# %%
#leyendo el archivo CSV
df_exams = pd.read_csv('/StudentsPerformance.csv')

# %%
# MOSTRAR LAS PRIMERAS 5 FILAS DEL DATAFRAME
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
# mostrar ultimas 5 filas del dataframe
df_exams = pd.read_csv('/StudentsPerformance.csv')

# %%
# mostrar ultimas n filas del dataframe

# %%
# accediendo al atributo  shape

# %%
# mostrar "n" filas

# %%
#

# %%
#
